# %%
import matplotlib.pyplot as plt
import pandas as pd
import math
import numpy as np
from iminuit import Minuit

# %% [markdown]
# Inizio ad importare il file

# %%
df = pd.read_excel('ArchivioLotto.italia.xlsx')

# %%
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0    1939-01-07         NaN           7          38          40          57
# 1    1939-01-14         NaN          35          24          41          52
# 2    1939-01-21         NaN          27          23          37          12
# 3    1939-01-28         NaN          50          85          47          18
# 4    1939-02-04         NaN          15          37          14          84
# ...         ...         ...         ...         ...         ...         ...
# 6398 2021-07-06         NaN          21          43          16           9
# 6399 2021-07-08         NaN          81          73          17          34
# 6400 2021-07-10         NaN          79          64          23          89
# 6401 2021-07-13         NaN          34          66          84           3
# 6402 2021-07-15         NaN          74          76          50          61
#
# ...

# %% [markdown]
# Dalla tabella prendo solo i dati relativi alle estrazioni di Milano (da filtrare ulteriormente)
